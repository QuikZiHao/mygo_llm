# %% [markdown]
# # Get yolo dataset for labelling

# %%
import src.classification_process.utils as utils

utils.get_dataset()

# %% [markdown]
# # train yolo

# %%
from src.classification_process.implement.train import train

# %%
train()
# Out:
# New https://pypi.org/project/ultralytics/8.3.53 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.50  Python-3.12.6 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from src.classification_process.utils.to_onnx import yolo_to_onnx

yolo_to_onnx(r"runs\detect\train\weights\best.pt",r"assets\models\my_go_yolov11.onnx")
# Out:
# Ultralytics 8.3.50  Python-3.12.6 torch-2.5.1+cu118 CPU (13th Gen Intel Core(TM) i7-13700H)
# YOLO11n summary (fused): 238 layers, 2,584,882 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs\detect\train\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 18, 8400) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.45...
# ONNX: export success  1.3s, saved as 'runs\detect\train\weights\best.onnx' (10.1 MB)
#
# Export complete (1.7s)
# Results saved to C:\Users\AORUS\Desktop\program\mygo_llm\runs\detect\train\weights
# Predict:         yolo predict task=detect model=runs\detect\train\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train\weights\best.onnx imgsz=640 data=assets/MY_GO.v3i.yolov11/data.yaml
# Visualize:       https://netron.app
# Model saved to: assets\models\my_go_yolov11.onnx

# %%
import os
yolo_pt_pathway = r'runs/detect/train14/weights/best.pt'
model_dir = os.path.dirname(yolo_pt_pathway)
os.path.basename(yolo_pt_pathway).split('.')[0]+".onnx"
# Out:
# 'best.onnx'

# %%
from ultralytics import YOLO

# Load the trained YOLOv5 model
model = YOLO(r'runs/detect/train11/weights/best.pt')  # Or use 'last.pt' for the last epoch model

# Export the model to ONNX format
onnx_output_path = r'assets/models/my_go_yolov11.onnx'  # Specify the desired ONNX file path
model.export(format='onnx')  # Export model to ONNX

# Move the ONNX file to a custom directory (optional)
os.rename(r'runs/detect/train14/weights/best.onnx',onnx_output_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 from ultralytics import YOLO
#       3 # Load the trained YOLOv5 model
# ----> 4 model = YOLO(r'runs/detect/train11/weights/best.pt')  # Or use 'last.pt' for the last epoch model
#       6 # Export the model to ONNX format
#       7 onnx_output_path = r'assets/models/my_go_yolov11.onnx'  # Specify the desired ONNX file path
#
# File c:\Users\AORUS\Desktop\program\mygo_llm\mygo\Lib\site-packages\ultralytics\models\yolo\model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# ...

# %%
import cv2
import numpy as np
import onnxruntime as ort

# Load the ONNX model
onnx_model_path = r"assets\models\my_go_yolov11.onnx"  # Path to your ONNX model
session = ort.InferenceSession(onnx_model_path)

# Prepare the input image (BCHW format)
image_path = r"C:\Users\AORUS\Desktop\program\mygo_llm\assets\frames\9\frame_011184.jpg"  # Replace with your image path
image = cv2.imread(image_path)  # Read the image using OpenCV

# Resize the image to the input size expected by the model (640x640 for YOLOv5)
image_resized = cv2.resize(image, (640, 640))

# Normalize the image (YOLOv5 expects input in [0, 1] range)
image_resized = image_resized / 255.0

# Convert the image to CHW format (Channels x Height x Width)
image_resized = np.transpose(image_resized, (2, 0, 1))

# Add batch dimension (1 x Channels x Height x Width)
image_resized = np.expand_dims(image_resized, axis=0).astype(np.float32)

# Run inference
inputs = {session.get_inputs()[0].name: image_resized}  # Feed the image to the model
outputs = session.run(None, inputs)  # Run the model

# Post-processing the outputs (adjust based on your model's output format)
# YOLOv5 outputs 1x18x8400 (for example), representing detections
output = outputs[0]  # Get the detections

# Now, output contains the detections, which need to be processed further (e.g., non-max suppression)
# You can decode the predictions as per YOLOv5 output format (boxes, labels, scores)

print("Inference output:", output)
# Out:
# Inference output: [[[     6.2437      12.931      27.276 ...      528.62      538.29      564.08]
#   [     23.859      21.629      9.4595 ...      594.96       605.1       599.3]
#   [     12.333      25.882       55.61 ...      201.14       188.2      156.86]
#   ...
#   [ 4.2915e-06  3.8594e-05  6.3181e-06 ...  0.00028983  9.2506e-05  2.7508e-05]
#   [ 3.1292e-06  1.0908e-05  2.5332e-06 ...  2.4468e-05  2.0057e-05  1.5855e-05]
#   [ 8.0466e-07  5.9903e-06  6.2585e-07 ...  2.2411e-05  1.4037e-05  1.2964e-05]]]

# %%
type(output)
# Out:
# numpy.ndarray

# %%
from ultralytics.utils import ops
import torch
preds = ops.non_max_suppression( torch.tensor(output),conf_thres=0.5,iou_thres=0.45,nc=13)

# %%
preds = np.array(preds)
preds = preds[0]

# %%
preds
# Out:
# array([[     120.85,      290.06,      206.71,      423.61,     0.79967,          10,  0.00023916],
#        [     420.35,      132.28,      456.55,      180.11,     0.75515,           2,   1.061e-05],
#        [     367.69,      26.463,      488.54,      233.98,     0.56561,           6,   0.0013657],
#        [  -0.047623,      19.786,      128.64,       263.4,      0.5591,          11,  0.00011447]], dtype=float32)

# %%
max_idx = 0
max_src = 0 
count = 0
for i in output:
    if i[5] >= max_src:
        max_src = i[5]
        max_idx = count
    count += 1

# %%
output[max_idx]
# Out:
# array([591.712   , 595.51105 , 603.8249  , 625.7446  , 632.1004  ,
#        635.46277 ,   5.404787,   9.446216,  21.677351,  25.372587,
#         32.21443 ,  41.092865,  50.449856,  53.797165,  60.045475,
#         73.329735,  83.83136 ,  91.55303 ], dtype=float32)

# %%
from PIL import Image, ImageDraw


# Load the image
image_path = r"C:\Users\AORUS\Desktop\program\mygo_llm\assets\frames\9\frame_011184.jpg"
image = Image.open(image_path)
image_resized = image.resize((640,640))
image_width, image_height = image_resized.size  # Store original dimensions


draw = ImageDraw.Draw(image_resized)

# Draw bounding boxes
for pred in preds:
    x1, y1, x2, y2, conf, cls ,_ = pred
    # Scale bounding box coordinates
    x1, y1 = x1 , y1
    x2, y2 = x2 , y2
    # Ensure coordinates stay within bounds
    x1, y1, x2, y2 = max(0, x1), max(0, y1), min(640, x2), min(640, y2)
    # Draw bounding box
    draw.rectangle([x1, y1, x2, y2], outline="red", width=3)
    # Add label (class and confidence)
    label = f"Class {int(cls)}, Conf {conf:.2f}"
    draw.text((x1, max(y1 - 10, 0)), label, fill="blue")
# Save or display the image
image_resized
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
from src.yolo_process.entity.predictior import YoloONNXPredictor

model = YoloONNXPredictor()
for i in range(20, 30): 
    temp = model.predict(fr"C:\Users\AORUS\Desktop\program\mygo_llm\assets\frames\10\frame_{i*360*3:06d}.jpg",show=True)
