# %% [markdown]
# # Get yolo dataset for labelling

# %%
import src.classification_process.utils as utils

utils.get_dataset

# %% [markdown]
# # train yolo

# %%
import src.classification_process.implement as implement

# %%
implement.get_resnet_dataset()
# Out:
# Saved cropped image 1.jpg in umirin
# Saved cropped image 1.jpg in taki
# Saved cropped image 1.jpg in mouth
# Saved cropped image 2.jpg in umirin
# Saved cropped image 2.jpg in taki
# Saved cropped image 2.jpg in mouth
# Saved cropped image 3.jpg in umirin
# Saved cropped image 3.jpg in taki
# Saved cropped image 3.jpg in mouth
# Saved cropped image 1.jpg in muzimi
# Saved cropped image 2.jpg in muzimi
# Saved cropped image 3.jpg in muzimi
# Saved cropped image 4.jpg in muzimi
# Saved cropped image 5.jpg in muzimi
# Saved cropped image 6.jpg in muzimi
# Saved cropped image 1.jpg in soyo
# Saved cropped image 1.jpg in other
# Saved cropped image 2.jpg in other
# Saved cropped image 3.jpg in other
# Saved cropped image 4.jpg in other
# Saved cropped image 7.jpg in muzimi
# Saved cropped image 5.jpg in other
# Saved cropped image 6.jpg in other
# Saved cropped image 2.jpg in soyo
# Saved cropped image 7.jpg in other
# Saved cropped image 8.jpg in other
# ...

# %%
from src.classification_process.utils.remake_dataset import remake_dataset
remake_dataset()

# %%
implement.train()
# Out:
# New https://pypi.org/project/ultralytics/8.3.54 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.50  Python-3.12.6 torch-2.5.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# ...

# %%
from src.classification_process.utils.to_onnx import yolo_to_onnx

yolo_to_onnx(r"runs\detect\train\weights\best.pt",r"assets\models\my_go_yolov11.onnx")
# Out:
# Ultralytics 8.3.50  Python-3.12.6 torch-2.5.1+cu118 CPU (13th Gen Intel Core(TM) i7-13700H)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# PyTorch: starting from 'runs\detect\train\weights\best.pt' with input shape (1, 3, 736, 736) BCHW and output shape(s) (1, 6, 11109) (5.2 MB)
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.45...
# ONNX: export success  122.1s, saved as 'runs\detect\train\weights\best.onnx' (10.1 MB)
#
# Export complete (122.3s)
# Results saved to C:\Users\AORUS\Desktop\program\mygo_llm\runs\detect\train\weights
# Predict:         yolo predict task=detect model=runs\detect\train\weights\best.onnx imgsz=736
# Validate:        yolo val task=detect model=runs\detect\train\weights\best.onnx imgsz=736 data=assets/MY_GO.v3i.yolov11/data.yaml
# Visualize:       https://netron.app
# Model saved to: assets\models\my_go_yolov11.onnx

# %%
from src.classification_process.utils.load_speech import load_speech
temp = load_speech(r"assets\speech\ass_result_chinese.xlsx")

# %%
temp
# Out:
# [[{'speech': '小祥',
#    'start_time': 31230,
#    'end_time': 32000,
#    'start_frame': 'frame_000756.jpg',
#    'end_frame': 'frame_000756.jpg',
#    'eps': 1,
#    'get_frame': 'frame_000768.jpg'},
#   {'speech': '太好了 妳終於來了',
#    'start_time': 32560,
#    'end_time': 34250,
#    'start_frame': 'frame_000792.jpg',
#    'end_frame': 'frame_000816.jpg',
#    'eps': 1,
#    'get_frame': 'frame_000804.jpg'},
#   {'speech': '怎麼濕成這樣 妳沒事吧',
#    'start_time': 34650,
#    'end_time': 36610,
#    'start_frame': 'frame_000840.jpg',
#    'end_frame': 'frame_000876.jpg',
#    'eps': 1,
#    'get_frame': 'frame_000864.jpg'},
#   {'speech': '妳最近不來學校 發消息也不回',
#    'start_time': 37070,
#    'end_time': 39930,
#    'start_frame': 'frame_000900.jpg',
#    'end_frame': 'frame_000948.jpg',
#    'eps': 1,
#    'get_frame': 'frame_000924.jpg'},
#   {'speech': '今天我來是有話要說',
#    'start_time': 42130,
#    'end_time': 43850,
#    'start_frame': 'frame_001020.jpg',
#    'end_frame': 'frame_001044.jpg',
# ...
